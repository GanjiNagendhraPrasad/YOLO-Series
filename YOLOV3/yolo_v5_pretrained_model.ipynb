# %%
# Install the ultralytics package
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.7 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17968, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 17968 (delta 72), reused 24 (delta 22), pack-reused 17870 (from 3)
# Receiving objects: 100% (17968/17968), 17.13 MiB | 20.23 MiB/s, done.
# Resolving deltas: 100% (12229/12229), done.

# %%
# %cd '/content/yolov5'
# Out:
# /content/yolov5

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	     README.zh-CN.md   train.py
# CITATION.cff	 detect.py   models	     requirements.txt  tutorial.ipynb
# classify	 export.py   pyproject.toml  segment	       utils
# CONTRIBUTING.md  hubconf.py  README.md	     tests	       val.py

# %%
# !wget https://github.com/ultralytics/yolov5/releases/download/v2.0/yolov5s.pt
# Out:
# --2026-05-07 14:46:33--  https://github.com/ultralytics/yolov5/releases/download/v2.0/yolov5s.pt
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# #Image

# %%
# !python detect.py --weights=/content/yolov5/yolov5s.pt --source=/content/yolov5/bus.jpg
# Out:
# detect: weights=['/content/yolov5/yolov5s.pt'], source=/content/yolov5/bus.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: Ultralytics requirement ['urllib3>=2.6.0 ; python_version > "3.8"'] not found, attempting AutoUpdate...
# WARNING ⚠️ Retry 1/2 failed: Command 'uv pip install --no-cache-dir --python "/usr/bin/python3" "urllib3>=2.6.0 ; python_version > "3.8""  --index-strategy=unsafe-best-match --break-system-packages' returned non-zero exit status 2.
# ...

# %%
# !python detect.py --weights=/content/yolov5/yolov5s.pt --source=/content/yolov5/yolo_test.mp4
# Out:
# detect: weights=['/content/yolov5/yolov5s.pt'], source=/content/yolov5/yolo_test.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: Ultralytics requirement ['urllib3>=2.6.0 ; python_version > "3.8"'] not found, attempting AutoUpdate...
# WARNING ⚠️ Retry 1/2 failed: Command 'uv pip install --no-cache-dir --python "/usr/bin/python3" "urllib3>=2.6.0 ; python_version > "3.8""  --index-strategy=unsafe-best-match --break-system-packages' returned non-zero exit status 2.
# ...
