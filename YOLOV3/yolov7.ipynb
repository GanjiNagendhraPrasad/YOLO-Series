# %%
# %ls
# Out:
# check_data.zip  sample_data/

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 17.13 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %%
# %ls
# Out:
# cfg/       export.py   LICENSE.md  requirements.txt  train_aux.py
# data/      figure/     models/     scripts/          train.py
# deploy/    hubconf.py  paper/      test.py           utils/
# detect.py  inference/  README.md   tools/

# %%
! wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Out:
# --2026-05-13 14:10:43--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# #Image

# %%
# !python detect.py --weights /content/yolov7/yolov7.pt --source /content/yolov7/bus.jpg
# Out:
# Namespace(weights=['/content/yolov7/yolov7.pt'], source='/content/yolov7/bus.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.10.0+cu128 CUDA:0 (Tesla T4, 14912.6875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python detect.py --weights yolov7.pt --source inference/images/horses.jpg
# Out:
# Namespace(weights=['yolov7.pt'], source='inference/images/horses.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.10.0+cu128 CUDA:0 (Tesla T4, 14912.6875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python detect.py --weights yolov7.pt --source /content/yolov7/yolo_test.mp4
# Out:
# Namespace(weights=['yolov7.pt'], source='/content/yolov7/yolo_test.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.10.0+cu128 CUDA:0 (Tesla T4, 14912.6875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# #custom data train

# %%
# !unzip "/content/check_data.zip" -d "/content/"
# Out:
# Archive:  /content/check_data.zip
#    creating: /content/check_data/
#    creating: /content/check_data/test/
#   inflating: /content/check_data/test/393.jpg
#   inflating: /content/check_data/test/393.txt
#   inflating: /content/check_data/test/394.jpg
#   inflating: /content/check_data/test/394.txt
#   inflating: /content/check_data/test/395.jpg
#   inflating: /content/check_data/test/395.txt
#   inflating: /content/check_data/test/396.jpg
#   inflating: /content/check_data/test/396.txt
#   inflating: /content/check_data/test/397.jpg
#   inflating: /content/check_data/test/397.txt
#   inflating: /content/check_data/test/398.jpg
#   inflating: /content/check_data/test/398.txt
#   inflating: /content/check_data/test/399.jpg
#   inflating: /content/check_data/test/399.txt
#   inflating: /content/check_data/test/400.jpg
#   inflating: /content/check_data/test/400.txt
#   inflating: /content/check_data/test/401.jpg
#   inflating: /content/check_data/test/401.txt
# ...

# %%
# !python train.py --weights yolov7.pt --data /content/yolov7/data/custom_data.yaml --cfg  cfg/training/yolov7.yaml --name kamal --hyp /content/yolov7/data/hyp.scratch.custom.yaml --epochs 10
# Out:
# 2026-05-13 14:42:10.796981: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# YOLOR 🚀 v0.1-128-ga207844 torch 2.10.0+cu128 CUDA:0 (Tesla T4, 14912.6875MB)
#
# ...

# %% [markdown]
# #v8 Detection

# %%
# %cd /content
# Out:
# /content

# %%
# %ls
# Out:
# check_data/  check_data.zip  sample_data/  yolov7/

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Display model information (optional)
model.info()


# Run inference with the YOLOv8n model on the 'bus.jpg' image
results = model("/content/yolov7/yolo_test.mp4")
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/630) /content/yolov7/yolo_test.mp4: 384x640 7 persons, 3 cars, 1 bus, 1 handbag, 80.0ms
# video 1/1 (frame 2/630) /content/yolov7/yolo_test.mp4: 384x640 8 persons, 2 cars, 1 bus, 1 handbag, 7.0ms
# video 1/1 (frame 3/630) /content/yolov7/yolo_test.mp4: 384x640 9 persons, 2 cars, 1 bus, 1 handbag, 6.2ms
# ...

# %% [markdown]
# #yolov7_segmentation

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 14.26 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %%
# !git checkout 44f30af0daccb1a3baecc5d80eae22948516c579
# Out:
# Note: switching to '44f30af0daccb1a3baecc5d80eae22948516c579'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 44f30af u7 readme

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-seg.pt
# Out:
# --2026-05-13 15:02:59--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-seg.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python seg/segment/predict.py --weights /content/yolov7/yolov7-seg.pt --source /content/yolov7/bus.jpg
# Out:
# segment/predict: weights=['/content/yolov7/yolov7-seg.pt'], source=/content/yolov7/bus.jpg, data=seg/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=seg/runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2026-5-13 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# yolov7-iseg summary: 325 layers, 38268602 parameters, 0 gradients
# image 1/1 /content/yolov7/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, 58.9ms
# Speed: 0.6ms pre-process, 58.9ms inference, 76.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to seg/runs/predict-seg/exp3
